# %%
from __future__ import print_function

from keras.models import Model
from keras.layers import Input, LSTM, Dense
import numpy as np

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = 'ben.txt'

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')

# %%
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

# %%
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

# %%
print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 6509
# Number of unique input tokens: 75
# Number of unique output tokens: 92
# Max sequence length for inputs: 134
# Max sequence length for outputs: 125

# %%
input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

# %%
"""Turn the sentences into 3 Numpy arrays, encoder_input_data, decoder_input_data, decoder_target_data:

encoder_input_data is a 3D array of shape (num_pairs, max_english_sentence_length, num_english_characters) containing a one-hot vectorization of the English sentences
decoder_input_data is a 3D array of shape (num_pairs, max_french_sentence_length, num_french_characters) containing a one-hot vectorization of the French sentences
decoder_target_data is the same as decoder_input_data but offset by one timestep. decoder_target_data[:, t, :] will be the same as decoder_input_data[:, t + 1, :]
"""

encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length, num_encoder_tokens),dtype='float32')
decoder_input_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_tokens),dtype='float32')
decoder_target_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_tokens),dtype='float32')

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    encoder_input_data[i, t + 1:, input_token_index[' ']] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
    decoder_input_data[i, t + 1:, target_token_index[' ']] = 1.
    decoder_target_data[i, t:, target_token_index[' ']] = 1.

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# %%
# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
#Train a basic LSTM-based Seq2Seq model to predict decoder_target_data given encoder_input_data and decoder_input_data

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model2 = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
# Run training
model2.compile(optimizer='rmsprop', loss='categorical_crossentropy',
              metrics=['accuracy'])
model2.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Save model
model2.save('ben-eng.h5')
# Out:
# Epoch 1/100
# 82/82 [==============================] - 260s 3s/step - loss: 0.8882 - accuracy: 0.8362 - val_loss: 1.4462 - val_accuracy: 0.7310
# Epoch 2/100
# 82/82 [==============================] - 241s 3s/step - loss: 0.6393 - accuracy: 0.8522 - val_loss: 1.2360 - val_accuracy: 0.7310
# Epoch 3/100
# 82/82 [==============================] - 201s 2s/step - loss: 0.5953 - accuracy: 0.8514 - val_loss: 1.1310 - val_accuracy: 0.7310
# Epoch 4/100
# 82/82 [==============================] - 174s 2s/step - loss: 0.5755 - accuracy: 0.8526 - val_loss: 1.0698 - val_accuracy: 0.7260
# Epoch 5/100
# 82/82 [==============================] - 165s 2s/step - loss: 0.5489 - accuracy: 0.8577 - val_loss: 1.0252 - val_accuracy: 0.7362
# Epoch 6/100
# 82/82 [==============================] - 181s 2s/step - loss: 0.5249 - accuracy: 0.8669 - val_loss: 0.9910 - val_accuracy: 0.7499
# Epoch 7/100
# 82/82 [==============================] - 160s 2s/step - loss: 0.4892 - accuracy: 0.8756 - val_loss: 0.9275 - val_accuracy: 0.7628
# Epoch 8/100
# 82/82 [==============================] - 174s 2s/step - loss: 0.4645 - accuracy: 0.8797 - val_loss: 0.8671 - val_accuracy: 0.7766
# Epoch 9/100
# 82/82 [==============================] - 158s 2s/step - loss: 0.4367 - accuracy: 0.8852 - val_loss: 0.8552 - val_accuracy: 0.7792
# Epoch 10/100
# 82/82 [==============================] - 174s 2s/step - loss: 0.4193 - accuracy: 0.8890 - val_loss: 0.8186 - val_accuracy: 0.7861
# Epoch 11/100
# 82/82 [==============================] - 165s 2s/step - loss: 0.4767 - accuracy: 0.8821 - val_loss: 0.7990 - val_accuracy: 0.7903
# Epoch 12/100
# 82/82 [==============================] - 172s 2s/step - loss: 0.3977 - accuracy: 0.8938 - val_loss: 0.7892 - val_accuracy: 0.7916
# Epoch 13/100
# 82/82 [==============================] - 167s 2s/step - loss: 0.3894 - accuracy: 0.8951 - val_loss: 0.7816 - val_accuracy: 0.7909
# Epoch 14/100
# 82/82 [==============================] - 166s 2s/step - loss: 0.3820 - accuracy: 0.8966 - val_loss: 0.7679 - val_accuracy: 0.7939
# Epoch 15/100
# 82/82 [==============================] - 169s 2s/step - loss: 0.3751 - accuracy: 0.8982 - val_loss: 0.7786 - val_accuracy: 0.7924
# Epoch 16/100
# 82/82 [==============================] - 170s 2s/step - loss: 0.3691 - accuracy: 0.8996 - val_loss: 0.7614 - val_accuracy: 0.7958
# Epoch 17/100
# 82/82 [==============================] - 189s 2s/step - loss: 0.3640 - accuracy: 0.9010 - val_loss: 0.7600 - val_accuracy: 0.7944
# Epoch 18/100
# 82/82 [==============================] - 179s 2s/step - loss: 0.3593 - accuracy: 0.9022 - val_loss: 0.7385 - val_accuracy: 0.8015
# Epoch 19/100
# 82/82 [==============================] - 190s 2s/step - loss: 0.3910 - accuracy: 0.8992 - val_loss: 0.7695 - val_accuracy: 0.7975
# Epoch 20/100
# 82/82 [==============================] - 171s 2s/step - loss: 0.3516 - accuracy: 0.9043 - val_loss: 0.7300 - val_accuracy: 0.8050
# Epoch 21/100
# 82/82 [==============================] - 205s 2s/step - loss: 0.3481 - accuracy: 0.9050 - val_loss: 0.7434 - val_accuracy: 0.8001
# Epoch 22/100
# 82/82 [==============================] - 208s 3s/step - loss: 0.3448 - accuracy: 0.9055 - val_loss: 0.7298 - val_accuracy: 0.8011
# Epoch 23/100
# 82/82 [==============================] - 190s 2s/step - loss: 0.3409 - accuracy: 0.9064 - val_loss: 0.7353 - val_accuracy: 0.8000
# Epoch 24/100
# 82/82 [==============================] - 172s 2s/step - loss: 0.3376 - accuracy: 0.9071 - val_loss: 0.7373 - val_accuracy: 0.8011
# Epoch 25/100
# 82/82 [==============================] - 135s 2s/step - loss: 0.3342 - accuracy: 0.9078 - val_loss: 0.7169 - val_accuracy: 0.8060
# Epoch 26/100
# 82/82 [==============================] - 150s 2s/step - loss: 0.3311 - accuracy: 0.9088 - val_loss: 0.7046 - val_accuracy: 0.8073
# Epoch 27/100
# 82/82 [==============================] - 134s 2s/step - loss: 0.3280 - accuracy: 0.9095 - val_loss: 0.7160 - val_accuracy: 0.8058
# Epoch 28/100
# 82/82 [==============================] - 150s 2s/step - loss: 0.3248 - accuracy: 0.9103 - val_loss: 0.7027 - val_accuracy: 0.8080
# Epoch 29/100
# 82/82 [==============================] - 149s 2s/step - loss: 0.3218 - accuracy: 0.9110 - val_loss: 0.7093 - val_accuracy: 0.8064
# Epoch 30/100
# 82/82 [==============================] - 149s 2s/step - loss: 0.3189 - accuracy: 0.9116 - val_loss: 0.7106 - val_accuracy: 0.8068
# Epoch 31/100
# 82/82 [==============================] - 142s 2s/step - loss: 0.3160 - accuracy: 0.9125 - val_loss: 0.6992 - val_accuracy: 0.8106
# Epoch 32/100
# 82/82 [==============================] - 148s 2s/step - loss: 0.3135 - accuracy: 0.9128 - val_loss: 0.7029 - val_accuracy: 0.8088
# Epoch 33/100
# 82/82 [==============================] - 138s 2s/step - loss: 0.3107 - accuracy: 0.9136 - val_loss: 0.6877 - val_accuracy: 0.8144
# Epoch 34/100
# 82/82 [==============================] - 147s 2s/step - loss: 0.3078 - accuracy: 0.9143 - val_loss: 0.6811 - val_accuracy: 0.8152
# Epoch 35/100
# 82/82 [==============================] - 141s 2s/step - loss: 0.3057 - accuracy: 0.9149 - val_loss: 0.6917 - val_accuracy: 0.8125
# Epoch 36/100
# 82/82 [==============================] - 146s 2s/step - loss: 0.3027 - accuracy: 0.9155 - val_loss: 0.6812 - val_accuracy: 0.8163
# Epoch 37/100
# 82/82 [==============================] - 147s 2s/step - loss: 0.3004 - accuracy: 0.9162 - val_loss: 0.6844 - val_accuracy: 0.8128
# Epoch 38/100
# 82/82 [==============================] - 146s 2s/step - loss: 0.2981 - accuracy: 0.9168 - val_loss: 0.6726 - val_accuracy: 0.8173
# Epoch 39/100
# 82/82 [==============================] - 124s 2s/step - loss: 0.2954 - accuracy: 0.9177 - val_loss: 0.6790 - val_accuracy: 0.8149
# Epoch 40/100
# 82/82 [==============================] - 124s 2s/step - loss: 0.2932 - accuracy: 0.9183 - val_loss: 0.6640 - val_accuracy: 0.8196
# Epoch 41/100
# 82/82 [==============================] - 121s 1s/step - loss: 0.2906 - accuracy: 0.9189 - val_loss: 0.6855 - val_accuracy: 0.8152
# Epoch 42/100
# 82/82 [==============================] - 125s 2s/step - loss: 0.2887 - accuracy: 0.9194 - val_loss: 0.6829 - val_accuracy: 0.8138
# Epoch 43/100
# 82/82 [==============================] - 124s 2s/step - loss: 0.2862 - accuracy: 0.9201 - val_loss: 0.6705 - val_accuracy: 0.8185
# Epoch 44/100
# 82/82 [==============================] - 122s 1s/step - loss: 0.2838 - accuracy: 0.9207 - val_loss: 0.6699 - val_accuracy: 0.8199
# Epoch 45/100
# 82/82 [==============================] - 123s 1s/step - loss: 0.2820 - accuracy: 0.9212 - val_loss: 0.6607 - val_accuracy: 0.8208
# Epoch 46/100
# 82/82 [==============================] - 178s 2s/step - loss: 0.2798 - accuracy: 0.9219 - val_loss: 0.6716 - val_accuracy: 0.8177
# Epoch 47/100
# 82/82 [==============================] - 145s 2s/step - loss: 0.2776 - accuracy: 0.9225 - val_loss: 0.6660 - val_accuracy: 0.8187
# Epoch 48/100
# 82/82 [==============================] - 144s 2s/step - loss: 0.2755 - accuracy: 0.9231 - val_loss: 0.6731 - val_accuracy: 0.8180
# Epoch 49/100
# 82/82 [==============================] - 141s 2s/step - loss: 0.2735 - accuracy: 0.9238 - val_loss: 0.6731 - val_accuracy: 0.8186
# Epoch 50/100
# 82/82 [==============================] - 141s 2s/step - loss: 0.2715 - accuracy: 0.9243 - val_loss: 0.6663 - val_accuracy: 0.8190
# Epoch 51/100
# 82/82 [==============================] - 142s 2s/step - loss: 0.2695 - accuracy: 0.9249 - val_loss: 0.6700 - val_accuracy: 0.8210
# Epoch 52/100
# 82/82 [==============================] - 143s 2s/step - loss: 0.2674 - accuracy: 0.9254 - val_loss: 0.6775 - val_accuracy: 0.8173
# Epoch 53/100
# 82/82 [==============================] - 164s 2s/step - loss: 0.2653 - accuracy: 0.9260 - val_loss: 0.6589 - val_accuracy: 0.8216
# Epoch 54/100
# 82/82 [==============================] - 175s 2s/step - loss: 0.2634 - accuracy: 0.9263 - val_loss: 0.6624 - val_accuracy: 0.8229
# Epoch 55/100
# 82/82 [==============================] - 156s 2s/step - loss: 0.2615 - accuracy: 0.9271 - val_loss: 0.6643 - val_accuracy: 0.8212
# Epoch 56/100
# 82/82 [==============================] - 144s 2s/step - loss: 0.2600 - accuracy: 0.9277 - val_loss: 0.6636 - val_accuracy: 0.8234
# Epoch 57/100
# 82/82 [==============================] - 156s 2s/step - loss: 0.2579 - accuracy: 0.9281 - val_loss: 0.6595 - val_accuracy: 0.8226
# Epoch 58/100
# 82/82 [==============================] - 134s 2s/step - loss: 0.2563 - accuracy: 0.9286 - val_loss: 0.6735 - val_accuracy: 0.8194
# Epoch 59/100
# 82/82 [==============================] - 149s 2s/step - loss: 0.2544 - accuracy: 0.9291 - val_loss: 0.6732 - val_accuracy: 0.8217
# Epoch 60/100
# 82/82 [==============================] - 129s 2s/step - loss: 0.2525 - accuracy: 0.9296 - val_loss: 0.6611 - val_accuracy: 0.8246
# Epoch 61/100
# 82/82 [==============================] - 147s 2s/step - loss: 0.2508 - accuracy: 0.9300 - val_loss: 0.6610 - val_accuracy: 0.8258
# Epoch 62/100
# 82/82 [==============================] - 131s 2s/step - loss: 0.2490 - accuracy: 0.9306 - val_loss: 0.6504 - val_accuracy: 0.8262
# Epoch 63/100
# 82/82 [==============================] - 153s 2s/step - loss: 0.2473 - accuracy: 0.9311 - val_loss: 0.6577 - val_accuracy: 0.8247
# Epoch 64/100
# 82/82 [==============================] - 131s 2s/step - loss: 0.2455 - accuracy: 0.9316 - val_loss: 0.6643 - val_accuracy: 0.8244
# Epoch 65/100
# 82/82 [==============================] - 146s 2s/step - loss: 0.2437 - accuracy: 0.9320 - val_loss: 0.6569 - val_accuracy: 0.8247
# Epoch 66/100
# 82/82 [==============================] - 141s 2s/step - loss: 0.2426 - accuracy: 0.9324 - val_loss: 0.6619 - val_accuracy: 0.8246
# Epoch 67/100
# 82/82 [==============================] - 152s 2s/step - loss: 0.2410 - accuracy: 0.9328 - val_loss: 0.6597 - val_accuracy: 0.8227
# Epoch 68/100
# 82/82 [==============================] - 130s 2s/step - loss: 0.2390 - accuracy: 0.9332 - val_loss: 0.6561 - val_accuracy: 0.8267
# Epoch 69/100
# 82/82 [==============================] - 146s 2s/step - loss: 0.2376 - accuracy: 0.9336 - val_loss: 0.6599 - val_accuracy: 0.8257
# Epoch 70/100
# 82/82 [==============================] - 132s 2s/step - loss: 0.2360 - accuracy: 0.9341 - val_loss: 0.6662 - val_accuracy: 0.8252
# Epoch 71/100
# 82/82 [==============================] - 149s 2s/step - loss: 0.2344 - accuracy: 0.9348 - val_loss: 0.6820 - val_accuracy: 0.8230
# Epoch 72/100
# 82/82 [==============================] - 136s 2s/step - loss: 0.2328 - accuracy: 0.9350 - val_loss: 0.6756 - val_accuracy: 0.8230
# Epoch 73/100
# 82/82 [==============================] - 145s 2s/step - loss: 0.2313 - accuracy: 0.9355 - val_loss: 0.6634 - val_accuracy: 0.8251
# Epoch 74/100
# 82/82 [==============================] - 130s 2s/step - loss: 0.2296 - accuracy: 0.9360 - val_loss: 0.6718 - val_accuracy: 0.8256
# Epoch 75/100
# 82/82 [==============================] - 144s 2s/step - loss: 0.2282 - accuracy: 0.9363 - val_loss: 0.6702 - val_accuracy: 0.8250
# Epoch 76/100
# 82/82 [==============================] - 130s 2s/step - loss: 0.2264 - accuracy: 0.9368 - val_loss: 0.6591 - val_accuracy: 0.8279
# Epoch 77/100
# 82/82 [==============================] - 150s 2s/step - loss: 0.2252 - accuracy: 0.9372 - val_loss: 0.6728 - val_accuracy: 0.8267
# Epoch 78/100
# 82/82 [==============================] - 131s 2s/step - loss: 0.2236 - accuracy: 0.9375 - val_loss: 0.6779 - val_accuracy: 0.8240
# Epoch 79/100
# 82/82 [==============================] - 146s 2s/step - loss: 0.2224 - accuracy: 0.9378 - val_loss: 0.6725 - val_accuracy: 0.8255
# Epoch 80/100
# 82/82 [==============================] - 131s 2s/step - loss: 0.2207 - accuracy: 0.9383 - val_loss: 0.6764 - val_accuracy: 0.8246
# Epoch 81/100
# 82/82 [==============================] - 145s 2s/step - loss: 0.2195 - accuracy: 0.9385 - val_loss: 0.6712 - val_accuracy: 0.8253
# Epoch 82/100
# 82/82 [==============================] - 132s 2s/step - loss: 0.2178 - accuracy: 0.9391 - val_loss: 0.6833 - val_accuracy: 0.8246
# Epoch 83/100
# 82/82 [==============================] - 149s 2s/step - loss: 0.2164 - accuracy: 0.9395 - val_loss: 0.6908 - val_accuracy: 0.8244
# Epoch 84/100
# 82/82 [==============================] - 133s 2s/step - loss: 0.2151 - accuracy: 0.9398 - val_loss: 0.6889 - val_accuracy: 0.8246
# Epoch 85/100
# 82/82 [==============================] - 147s 2s/step - loss: 0.2134 - accuracy: 0.9402 - val_loss: 0.6840 - val_accuracy: 0.8235
# Epoch 86/100
# 82/82 [==============================] - 132s 2s/step - loss: 0.2122 - accuracy: 0.9406 - val_loss: 0.6955 - val_accuracy: 0.8244
# Epoch 87/100
# 82/82 [==============================] - 148s 2s/step - loss: 0.2109 - accuracy: 0.9410 - val_loss: 0.6873 - val_accuracy: 0.8267
# Epoch 88/100
# 82/82 [==============================] - 131s 2s/step - loss: 0.2095 - accuracy: 0.9412 - val_loss: 0.6982 - val_accuracy: 0.8248
# Epoch 89/100
# 82/82 [==============================] - 152s 2s/step - loss: 0.2081 - accuracy: 0.9419 - val_loss: 0.6963 - val_accuracy: 0.8236
# Epoch 90/100
# 82/82 [==============================] - 131s 2s/step - loss: 0.2069 - accuracy: 0.9421 - val_loss: 0.6911 - val_accuracy: 0.8249
# Epoch 91/100
# 82/82 [==============================] - 149s 2s/step - loss: 0.2055 - accuracy: 0.9425 - val_loss: 0.7045 - val_accuracy: 0.8230
# Epoch 92/100
# 82/82 [==============================] - 132s 2s/step - loss: 0.2039 - accuracy: 0.9431 - val_loss: 0.6906 - val_accuracy: 0.8261
# Epoch 93/100
# 82/82 [==============================] - 149s 2s/step - loss: 0.2027 - accuracy: 0.9434 - val_loss: 0.6888 - val_accuracy: 0.8263
# Epoch 94/100
# 82/82 [==============================] - 131s 2s/step - loss: 0.2016 - accuracy: 0.9437 - val_loss: 0.7032 - val_accuracy: 0.8244
# Epoch 95/100
# 82/82 [==============================] - 146s 2s/step - loss: 0.2002 - accuracy: 0.9439 - val_loss: 0.7084 - val_accuracy: 0.8235
# Epoch 96/100
# 82/82 [==============================] - 134s 2s/step - loss: 0.1989 - accuracy: 0.9442 - val_loss: 0.7172 - val_accuracy: 0.8223
# Epoch 97/100
# 82/82 [==============================] - 148s 2s/step - loss: 0.1975 - accuracy: 0.9447 - val_loss: 0.7126 - val_accuracy: 0.8231
# Epoch 98/100
# 82/82 [==============================] - 148s 2s/step - loss: 0.1960 - accuracy: 0.9452 - val_loss: 0.7002 - val_accuracy: 0.8253
# Epoch 99/100
# 82/82 [==============================] - 157s 2s/step - loss: 0.1954 - accuracy: 0.9453 - val_loss: 0.7128 - val_accuracy: 0.8224
# Epoch 100/100
# 82/82 [==============================] - 134s 2s/step - loss: 0.1940 - accuracy: 0.9458 - val_loss: 0.7171 - val_accuracy: 0.8240
# c:\Users\user\miniconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Define sampling models
encoder_model = Model(encoder_inputs, encoder_states)

# %%
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# %%
# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(10):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 47ms/step
# -
# Input sentence: Go.
# Decoded sentence: আমি এখনো আমার কাছে একটা পান করতে পারি?
#
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# -
# Input sentence: Go.
# Decoded sentence: আমি এখনো আমার কাছে একটা পান করতে পারি?
#
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# -
# Input sentence: Go.
# Decoded sentence: আমি এখনো আমার কাছে একটা পান করতে পারি?
#
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 272ms/step
# 1/1 [==============================] - 0s 280ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# -
# Input sentence: Run!
# Decoded sentence: আমি এখনো আমার কাছে একটা পান করতে পারি?
#
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 49ms/step
# -
# Input sentence: Run!
# Decoded sentence: আমি এখনো আমার কাছে একটা পান করতে পারি?
#
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 43ms/step
# -
# Input sentence: Who?
# Decoded sentence: আমি এখনো আমার কাছে একটা পান করতে পারি?
#
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# -
# Input sentence: Wow!
# Decoded sentence: আমি এখনো আমার কাছে একটা পান করতে পারি?
#
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# -
# Input sentence: Fire!
# Decoded sentence: আমি এখনো আমার কাছে একটা পান করতে পারি?
#
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# -
# Input sentence: Help!
# Decoded sentence: আমি এখনো আমার কাছে একটা পান করতে পারি?
#
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# -
# Input sentence: Help!
# Decoded sentence: আমি এখনো আমার কাছে একটা পান করতে পারি?
